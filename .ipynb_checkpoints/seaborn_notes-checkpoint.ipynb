# %% [markdown]
# [Seaborn](http://seaborn.pydata.org) is a Python visualization library based on matplotlib.
# It provides a high-level interface for drawing attractive **statistical graphics**.

# %%
# %matplotlib inline

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(sum(map(ord, "aesthetics")))

# %%
## Style management:

There are five preset seaborn themes: 
    darkgrid, whitegrid, dark, white, and ticks

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

# %%
# seaborn defaults
sns.set_style("dark")
sinplot()

# %%
sns.set_style("ticks")
sinplot()

# %%
# removing axes spines
sinplot()
sns.despine()

# %%
sns.set_style("whitegrid")
data = np.random.normal(size=(20, 6)) + np.arange(6) / 2
sns.boxplot(data=data);

# %%
f, ax = plt.subplots()
sns.violinplot(data=data)
sns.despine(offset=10, trim=True);

# %%
## Choosing color palettes

# %%
x, y = np.random.multivariate_normal([0, 0], [[1, -.5], [-.5, 1]], size=300).T
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
sns.kdeplot(x, y, cmap=cmap, shade=True)

# %%
pal = sns.dark_palette("palegreen", as_cmap=True)
sns.kdeplot(x, y, cmap=pal);

# %%
## Plotting functions

# %%
### 3.1 Visualizing the distribution
x = np.random.normal(size=100)
sns.distplot(x);

# %%
sns.distplot(x, kde=False, rug=True);

# %%
## 3.2 Visualizing pairwise relationships

# %%
iris = sns.load_dataset("iris")
sns.pairplot(iris);

# %%
### 3.3 Plotting with categorical 
sns.set(style="whitegrid", color_codes=True)
np.random.seed(sum(map(ord, "categorical")))

# dataset
titanic = sns.load_dataset("titanic")
tips = sns.load_dataset("tips")
iris = sns.load_dataset("iris")

# %%
sns.stripplot(x="day", y="total_bill", data=tips);

# %%
sns.boxplot(x="day", y="total_bill", hue="time", data=tips);

# %%
tips["weekend"] = tips["day"].isin(["Sat", "Sun"])
sns.boxplot(x="day", y="total_bill", hue="weekend", data=tips);

# %%
f, ax = plt.subplots(figsize=(7, 3))
sns.countplot(y="deck", data=titanic, color="c");

# %%
sns.factorplot(x="day", y="total_bill", hue="smoker", data=tips);

# %%
## 3.4 Visualizing linear relationships

# %%
sns.regplot(x="total_bill", y="tip", data=tips);

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips);

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="reg");
